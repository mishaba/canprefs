# %%
MyKey = "9MJDTPBV3KYJ6SMJ"

import pandas as pd

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data2, meta_data2 = ts.get_daily_adjusted(symbol='PWF-PT.TO', outputsize='full')
data2 = pd.read_pickle("./pwf_pr_t.av")

# %%
data2.head(3)
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2021-08-19    24.01    24.01   24.00     24.00              24.00      600.0
# 2021-08-18    24.14    24.24   24.13     24.13              24.13     1300.0
# 2021-08-17    24.21    24.21   24.14     24.14              24.14     1900.0
#
#             7. dividend amount  8. split coefficient
# date
# 2021-08-19                 0.0                   1.0
# 2021-08-18                 0.0                   1.0
# 2021-08-17                 0.0                   1.0

# %%
divs = data2[ data2['7. dividend amount'] != 0.0]
divs.head()

# %%
ax=df.loc['2013-06-15':'2021-07-30']['4. close'].plot(label='Foo',figsize=(16,8))

# %%
ax.axvline(x='2021-07-08')

# %%
zoom = df.loc['2021-06-15':'2021-07-30']

# %%
ax=zoom['4. close'].plot()
ax.axvline("2021-07-08",color="red",linestyle="--")

# %%
#data2.to_pickle("./pwf_pr_t.av")

# %%
def plot_range_divs(df,start,stop):
    zoom = df.loc[start:stop]
    divs = zoom[ zoom['7. dividend amount'] != 0.0]

    ax = zoom['4. close'].plot(figsize=(16,8))
    for i in divs.index:
        ax.axvline(i,color="red",linestyle="--")
    
plot_range_divs(data2, '2021-01-01','2021-08-18')

# %%
ax.axhline(20)

# %%
# Out:
# []
